# %%
import pandas as pd

# %%
data = pd.read_csv("../models/data/ML_Features.csv")

# %%
data.head()
# Out:
#              county                                coordinates percpopbroad  \
# 0    Jackson County     (-84.00617164501776 37.41979135091643)         99.6
# 1  Alleghany County       (-81.127710400513 36.49135989086295)         87.7
# 2     Gilmer County     (-84.45574304407471 34.69141719651767)         95.1
# 3     Butler County     (-96.83878537246211 37.78134351385873)         73.3
# 4   Imperial County    (-115.36572183649179 33.03935668641129)         85.7
#
#   percpopwobroad  pctdsgt15000kandlt25000k_hi  pctdsgt25000kandlt50000k_hi  \
# 0            0.4                          0.4                          0.0
# 1           12.3                         12.3                          0.0
# 2            4.9                          4.9                          0.0
# 3           26.7                         26.7                          2.4
# 4           14.3                         14.3                          0.2
#
# ...

# %%
# Delete unnamed columns
del data['Unnamed: 13']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Unnamed: 13', 'Unnamed: 14')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-92227844b794> in <module>
# ...

# %%
data = data.drop(["Unnamed: 16", "Unnamed: 17", "Unnamed: 18"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-fdba91098a37> in <module>
# ----> 1 data = data.drop(["Unnamed: 16", "Unnamed: 17", "Unnamed: 18"], axis=1)
#       2 data.head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
data.head()
# Out:
#              county                                coordinates percpopbroad  \
# 0    Jackson County     (-84.00617164501776 37.41979135091643)         99.6
# 1  Alleghany County       (-81.127710400513 36.49135989086295)         87.7
# 2     Gilmer County     (-84.45574304407471 34.69141719651767)         95.1
# 3     Butler County     (-96.83878537246211 37.78134351385873)         73.3
# 4   Imperial County    (-115.36572183649179 33.03935668641129)         85.7
#
#   percpopwobroad  pctdsgt15000kandlt25000k_hi  pctdsgt25000kandlt50000k_hi  \
# 0            0.4                          0.4                          0.0
# 1           12.3                         12.3                          0.0
# 2            4.9                          4.9                          0.0
# 3           26.7                         26.7                          2.4
# 4           14.3                         14.3                          0.2
#
# ...
