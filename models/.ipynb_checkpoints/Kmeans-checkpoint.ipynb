# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
# Read the data
data = pd.read_csv("data/Master.csv")
data
# Out:
#        Unnamed: 0  zipcode RegionType StateName        City           Metro  \
# 0               0      602        Zip        AL      Auburn  Auburn-Opelika
# 1               1      606        Zip        MO      Neosho          Joplin
# 2               2      610        Zip        KY      Anasco             NaN
# 3               3      617        Zip        AL      Imbery      Enterprise
# 4               4      693        Zip        PA  Greensburg      Pittsburgh
# ...           ...      ...        ...       ...         ...             ...
# 29733       29733    99827        Zip        AK      Haines             NaN
# 29734       29734    99833        Zip        AK  Petersburg             NaN
# 29735       29735    99835        Zip        AK       Sitka             NaN
# 29736       29736    99901        Zip        AK   Ketchikan       Ketchikan
# 29737       29737    99929        Zip        AK    Wrangell             NaN
#
#                       CountyName  AVERAGE  PRICE  Income per capita  \
# 0                     Lee County     114105.2500             9277.0
# 1                  Newton County      59377.7500             5943.0
# 2                    Pike County     108219.5833            10220.0
# 3                  Coffee County     101022.0000             9122.0
# 4            Westmoreland County     330761.5000            10536.0
# ...                          ...             ...                ...
# 29733             Haines Borough     211487.0000            33387.0
# 29734         Petersburg Borough     254642.9167            33227.0
# 29735              Sitka Borough     402391.3333            38423.0
# 29736  Ketchikan Gateway Borough     294448.8333            34886.0
# 29737           Wrangell Borough     215225.5833            31489.0
#
#        Median Age Male  Median Age Female  Bachelor's degree > 25  \
# 0                 41.9               42.8                0.134690
# 1                 43.2               43.4                0.068866
# 2                 40.4               44.2                0.130349
# 3                 39.2               41.0                0.157224
# 4                 39.2               41.9                0.148064
# ...                ...                ...                     ...
# 29733             45.2               45.8                0.229525
# 29734             39.3               42.7                0.219672
# 29735             37.2               40.5                0.204494
# 29736             39.4               39.9                0.170142
# 29737             51.6               48.3                0.140267
#
#        Public transportation
# 0                   0.002796
# 1                   0.000000
# 2                   0.002741
# 3                   0.005154
# 4                   0.006750
# ...                      ...
# 29733               0.002308
# 29734               0.009211
# 29735               0.010178
# 29736               0.035648
# 29737               0.006635
#
# [29738 rows x 13 columns]

# %%
# Remove strings
data_num = data.drop(columns=['Unnamed: 0','RegionType', 'StateName','City','Metro','CountyName'])
data_num
# Out:
#        zipcode  AVERAGE  PRICE  Income per capita  Median Age Male  \
# 0          602     114105.2500             9277.0             41.9
# 1          606      59377.7500             5943.0             43.2
# 2          610     108219.5833            10220.0             40.4
# 3          617     101022.0000             9122.0             39.2
# 4          693     330761.5000            10536.0             39.2
# ...        ...             ...                ...              ...
# 29733    99827     211487.0000            33387.0             45.2
# 29734    99833     254642.9167            33227.0             39.3
# 29735    99835     402391.3333            38423.0             37.2
# 29736    99901     294448.8333            34886.0             39.4
# 29737    99929     215225.5833            31489.0             51.6
#
#        Median Age Female  Bachelor's degree > 25  Public transportation
# 0                   42.8                0.134690               0.002796
# 1                   43.4                0.068866               0.000000
# 2                   44.2                0.130349               0.002741
# 3                   41.0                0.157224               0.005154
# 4                   41.9                0.148064               0.006750
# ...                  ...                     ...                    ...
# 29733               45.8                0.229525               0.002308
# 29734               42.7                0.219672               0.009211
# 29735               40.5                0.204494               0.010178
# 29736               39.9                0.170142               0.035648
# 29737               48.3                0.140267               0.006635
#
# [29738 rows x 7 columns]

# %%
data_num.set_index('zipcode',inplace=True)
data_num
# Out:
#          AVERAGE  PRICE  Income per capita  Median Age Male  \
# zipcode
# 602         114105.2500             9277.0             41.9
# 606          59377.7500             5943.0             43.2
# 610         108219.5833            10220.0             40.4
# 617         101022.0000             9122.0             39.2
# 693         330761.5000            10536.0             39.2
# ...                 ...                ...              ...
# 99827       211487.0000            33387.0             45.2
# 99833       254642.9167            33227.0             39.3
# 99835       402391.3333            38423.0             37.2
# 99901       294448.8333            34886.0             39.4
# 99929       215225.5833            31489.0             51.6
#
#          Median Age Female  Bachelor's degree > 25  Public transportation
# zipcode
# 602                   42.8                0.134690               0.002796
# 606                   43.4                0.068866               0.000000
# 610                   44.2                0.130349               0.002741
# 617                   41.0                0.157224               0.005154
# 693                   41.9                0.148064               0.006750
# ...                    ...                     ...                    ...
# 99827                 45.8                0.229525               0.002308
# 99833                 42.7                0.219672               0.009211
# 99835                 40.5                0.204494               0.010178
# 99901                 39.9                0.170142               0.035648
# 99929                 48.3                0.140267               0.006635
#
# [29738 rows x 6 columns]

# %%
# Assess data types
data_num.dtypes
# Out:
# AVERAGE  PRICE            float64
# Income per capita         float64
# Median Age Male           float64
# Median Age Female         float64
# Bachelor's degree > 25    float64
# Public transportation     float64
# dtype: object

# %%
# Find any Nan
data_num.isnull().values.any()
# Out:
# True

# %%
data_num.dropna( inplace=True)

# %%
data_num.isnull().values.any()
# Out:
# False

# %%
# Scale features
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
mms.fit(data_num)
data_transformed = mms.transform(data_num)

# %%
# Initialize k-means
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)

# %%
# Determine optimal clusters
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
# We chose 5 clusters
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)

# %%
# Perform prediction
data_predict = data_num['clusters'] = kmeans.fit_predict(data_num)

# %%
data_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# View cluster predictions
data_num
# Out:
#          AVERAGE  PRICE  Income per capita  Median Age Male  \
# zipcode
# 602         114105.2500             9277.0             41.9
# 606          59377.7500             5943.0             43.2
# 610         108219.5833            10220.0             40.4
# 617         101022.0000             9122.0             39.2
# 693         330761.5000            10536.0             39.2
# ...                 ...                ...              ...
# 99827       211487.0000            33387.0             45.2
# 99833       254642.9167            33227.0             39.3
# 99835       402391.3333            38423.0             37.2
# 99901       294448.8333            34886.0             39.4
# 99929       215225.5833            31489.0             51.6
#
#          Median Age Female  Bachelor's degree > 25  Public transportation  \
# zipcode
# 602                   42.8                0.134690               0.002796
# 606                   43.4                0.068866               0.000000
# 610                   44.2                0.130349               0.002741
# 617                   41.0                0.157224               0.005154
# 693                   41.9                0.148064               0.006750
# ...                    ...                     ...                    ...
# 99827                 45.8                0.229525               0.002308
# 99833                 42.7                0.219672               0.009211
# 99835                 40.5                0.204494               0.010178
# 99901                 39.9                0.170142               0.035648
# 99929                 48.3                0.140267               0.006635
#
#          clusters
# zipcode
# 602             0
# 606             0
# 610             0
# 617             0
# 693             0
# ...           ...
# 99827           0
# 99833           0
# 99835           0
# 99901           0
# 99929           0
#
# [29428 rows x 7 columns]

# %%
#from sklearn.decomposition import PCA
#reduced_data = PCA(n_components=2).fit_transform(data_num)
#results = pd.DataFrame(reduced_data,columns=['pca1','pca2'])

#sns.scatterplot(x="pca1", y="pca2", hue=data_num['clusters'], data=results)
#plt.title('K-means Clustering with 2 dimensions')
#plt.show()

# %%
# Export to csv for manual assessment
data_num.to_csv('data/cluster_predict.csv')
